# %%
# Timeline of the 2019–20 coronavirus pandemic in November 2019 – January 2020
nov19_jan20 = "https://en.wikipedia.org/wiki/Timeline_of_the_2019%E2%80%9320_coronavirus_pandemic_in_November_2019_%E2%80%93_January_2020"
feb20 = "https://en.wikipedia.org/wiki/Timeline_of_the_2019%E2%80%9320_coronavirus_pandemic_in_February_2020"
mar20 = "https://en.wikipedia.org/wiki/Timeline_of_the_2019%E2%80%9320_coronavirus_pandemic_in_March_2020"

# %%
import pandas as pd
import numpy as np
import bs4
import requests
import urllib
import urllib.request
import re

from bs4 import BeautifulSoup
from urllib.request import urlretrieve 
from urllib.request import urlopen, Request

# %%
html = urlopen(nov19_jan20)

soup = BeautifulSoup(html, 'lxml')

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.text)
# Out:
# Timeline of the 2019–20 coronavirus pandemic in November 2019 – January 2020 - Wikipedia
# ...

# %%
spans = soup.find_all("span")
for span in spans:
    print(span.get("id"))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# mw-customcollapsible-dec
# mw-customcollapsible-dec
# mw-customcollapsible-jan
# mw-customcollapsible-jan
# mw-customcollapsible-feb
# mw-customcollapsible-feb
# mw-customcollapsible-mar
# mw-customcollapsible-mar
# mw-customcollapsible-l15
# mw-customcollapsible-l15
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
